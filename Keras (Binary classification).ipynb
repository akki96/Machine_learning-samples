# %% [markdown]
# <a href="https://colab.research.google.com/github/akki96/Machine_learning-samples/blob/master/Keras%20(Binary%20classification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KEras single one evalutaion vid reference :- introduction to keras

# %%
#import section
import numpy as np 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

# %%
#generate Dummy Data
x_train = np.random.random((1000, 20))
y_train = np.random.randint(2, size=(1000,1))
x_test = np.random.random((1000, 20))
y_test = np.random.randint(2, size=(1000, 1))
print(len(x_train))
print(len(y_train))
#print(x_train)
#print(y_train)
# Out:
# 1000
# 1000

# %%
model = Sequential([
                    Dense(64, input_dim=20, activation='relu'),
                    Dense(10),
                    Dense(1,activation='sigmoid')]
)
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_49 (Dense)             (None, 64)                1344
# _________________________________________________________________
# dense_50 (Dense)             (None, 10)                650
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 11
# ...
# Total params: 2,005
# Trainable params: 2,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
#alternative
#model=Sequential()
#model.add(Dense(64, input_dim=20, activation='relu'))
#model.add(Dense(10))
#model.add(Dense(1, activation='sigmoid'))
#model.summary()

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          epochs=200,
          batch_size=128)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9880
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9450
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9840
# Epoch 4/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1488 - accuracy: 0.9370
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.9900
# Epoch 6/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1553 - accuracy: 0.9340
# Epoch 7/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.9920
# Epoch 8/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.9720
# Epoch 9/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1364 - accuracy: 0.9470
# Epoch 10/200
# ...

# %%
score = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2742 - accuracy: 0.4760
